# %%
# !pdm add langchain langgraph langchain-aws duckduckgo-search langchain-community
# Out:
# Adding packages to default dependencies: langchain, langgraph, langchain-aws,
# duckduckgo-search, langchain-community
# ⠦ 0:00:00 Resolve for environment (==3.12.*) None
# ⠏ 0:00:00 Resolve for environment (==3.12.*) None90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠹ 0:00:01 Resolve for environment (==3.12.*) 3 resolved, 15 to resolve resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠴ 0:00:01 Resolve for environment (==3.12.*) 4 resolved, 19 to resolve resolve0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠏ 0:00:01 Resolve for environment (==3.12.*) 5 resolved, 22 to resolve resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠹ 0:00:01 Resolve for environment (==3.12.*) 6 resolved, 23 to resolve resolve0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠴ 0:00:02 Resolve for environment (==3.12.*) 8 resolved, 27 to resolve resolve1m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠙ 0:00:02 Resolve for environment (==3.12.*) 11 resolved, 35 to resolveresolve0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠴ 0:00:02 Resolve for environment (==3.12.*) 11 resolved, 35 to resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠇ 0:00:03 Resolve for environment (==3.12.*) 11 resolved, 35 to resolve0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠙ 0:00:03 Resolve for environment (==3.12.*) 11 resolved, 35 to resolve0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠼ 0:00:03 Resolve for environment (==3.12.*) 11 resolved, 35 to resolve0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠧ 0:00:03 Resolve for environment (==3.12.*) 11 resolved, 35 to resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠙ 0:00:04 Resolve for environment (==3.12.*) 11 resolved, 35 to resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠼ 0:00:04 Resolve for environment (==3.12.*) 11 resolved, 35 to resolve0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠧ 0:00:04 Resolve for environment (==3.12.*) 12 resolved, 34 to resolve resolve1m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠋ 0:00:04 Resolve for environment (==3.12.*) 12 resolved, 34 to resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠧ 0:00:05 Resolve for environment (==3.12.*) 13 resolved, 36 to resolve resolve0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠋ 0:00:05 Resolve for environment (==3.12.*) 13 resolved, 36 to resolve0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠼ 0:00:05 Resolve for environment (==3.12.*) 13 resolved, 36 to resolve0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠧ 0:00:06 Resolve for environment (==3.12.*) 13 resolved, 36 to resolve0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠋ 0:00:06 Resolve for environment (==3.12.*) 13 resolved, 36 to resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠸ 0:00:06 Resolve for environment (==3.12.*) 13 resolved, 36 to resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠦ 0:00:06 Resolve for environment (==3.12.*) 13 resolved, 36 to resolve0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠋ 0:00:07 Resolve for environment (==3.12.*) 15 resolved, 38 to resolve resolve1m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠸ 0:00:07 Resolve for environment (==3.12.*) 15 resolved, 38 to resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠦ 0:00:07 Resolve for environment (==3.12.*) 16 resolved, 39 to resolve resolve0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠏ 0:00:07 Resolve for environment (==3.12.*) 16 resolved, 39 to resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠹ 0:00:08 Resolve for environment (==3.12.*) 16 resolved, 39 to resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠦ 0:00:08 Resolve for environment (==3.12.*) 16 resolved, 39 to resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠏ 0:00:08 Resolve for environment (==3.12.*) 17 resolved, 38 to resolve resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠹ 0:00:09 Resolve for environment (==3.12.*) 19 resolved, 38 to resolve resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠦ 0:00:09 Resolve for environment (==3.12.*) 19 resolved, 38 to resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠹ 0:00:09 Resolve for environment (==3.12.*) 22 resolved, 45 to resolve resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠴ 0:00:10 Resolve for environment (==3.12.*) 22 resolved, 45 to resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠏ 0:00:10 Resolve for environment (==3.12.*) 22 resolved, 45 to resolvem━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠹ 0:00:10 Resolve for environment (==3.12.*) 23 resolved, 45 to resolve resolvem━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠴ 0:00:10 Resolve for environment (==3.12.*) 24 resolved, 45 to resolve resolve90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠏ 0:00:11 Resolve for environment (==3.12.*) 27 resolved, 43 to resolve resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠹ 0:00:11 Resolve for environment (==3.12.*) 27 resolved, 43 to resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠴ 0:00:11 Resolve for environment (==3.12.*) 27 resolved, 43 to resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠇ 0:00:11 Resolve for environment (==3.12.*) 29 resolved, 46 to resolve resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠙ 0:00:12 Resolve for environment (==3.12.*) 29 resolved, 46 to resolvem━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠇ 0:00:12 Resolve for environment (==3.12.*) 38 resolved, 42 to resolve resolve0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠙ 0:00:12 Resolve for environment (==3.12.*) 45 resolved, 51 to resolve resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠼ 0:00:13 Resolve for environment (==3.12.*) 45 resolved, 51 to resolvem━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠧ 0:00:13 Resolve for environment (==3.12.*) 45 resolved, 51 to resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠼ 0:00:13 Resolve for environment (==3.12.*) 48 resolved, 53 to resolve resolve0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠧ 0:00:14 Resolve for environment (==3.12.*) 48 resolved, 53 to resolvem━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠋ 0:00:14 Resolve for environment (==3.12.*) 50 resolved, 55 to resolve resolve0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠸ 0:00:14 Resolve for environment (==3.12.*) 54 resolved, 51 to resolve resolvem━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠧ 0:00:14 Resolve for environment (==3.12.*) 54 resolved, 51 to resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠦ 0:00:15 Resolve for environment (==3.12.*) 68 resolved, 42 to resolve resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠸ 0:00:16 Resolve for environment (==3.12.*) 78 resolved, 41 to resolve resolvem━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠦ 0:00:16 Resolve for environment (==3.12.*) 78 resolved, 41 to resolve1m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠋ 0:00:16 Resolve for environment (==3.12.*) 78 resolved, 41 to resolve1m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠸ 0:00:17 Resolve for environment (==3.12.*) 78 resolved, 41 to resolve90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠦ 0:00:17 Resolve for environment (==3.12.*) 79 resolved, 40 to resolve resolve0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠋ 0:00:17 Resolve for environment (==3.12.*) 79 resolved, 40 to resolve0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠸ 0:00:17 Resolve for environment (==3.12.*) 80 resolved, 40 to resolve resolve1m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠏ 0:00:18 Resolve for environment (==3.12.*) 89 resolved, 42 to resolve resolvem━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠸ 0:00:18 Resolve for environment (==3.12.*) 89 resolved, 42 to resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠦ 0:00:18 Resolve for environment (==3.12.*) 91 resolved, 40 to resolve resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠹ 0:00:19 Resolve for environment (==3.12.*) 94 resolved, 45 to resolve resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠦ 0:00:20 Resolve for environment (==3.12.*) 127 resolved, 22 to resolveresolvem━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠴ 0:00:21 Resolve for environment (==3.12.*) 143 resolved, 12 to resolve resolvem━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠇ 0:00:21 Resolve for environment (==3.12.*) 152 resolved, 7 to resolvee resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   0:00:22 🔒 Lock successful.  nment (==3.12.*) Fetching hashes for resolved packageso resolve resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Changes are written to pyproject.toml.
# ⠋ Resolving packages from lockfile...
# All packages are synced to date, nothing to do.
#
# 0:00:00 Synchronizing 0/?
# 00 Synchronizing 0/0
# 00 🎉 All complete! 0/0
#   0:00:00 🎉 All complete! 0/0

# %%
from langchain_aws import ChatBedrock

model = ChatBedrock(model_id="anthropic.claude-3-5-sonnet-20240620-v1:0")

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search = DuckDuckGoSearchRun()

search.invoke("Obama's first name?")
# Out:
# 'Instead of her last name, she used just her first and middle names, Malia Ann, in the credits. And if you ask Barack Obama, his 23-year-old daughter, Sasha Obama, would do the same thing. 2 of 2. Barack Obama: timeline Key events in the life of Barack Obama. Barack Obama (born August 4, 1961, Honolulu, Hawaii, U.S.) is the 44th president of the United States (2009-17) and the first African American to hold the office. Before winning the presidency, Obama represented Illinois in the U.S. Senate (2005-08). Since the office was established in 1789, 45 men have served in 46 presidencies. The first president, George Washington, won a unanimous vote of the Electoral College. [4] Grover Cleveland served two non-consecutive terms and is therefore counted as the 22nd and 24th president of the United States, giving rise to the discrepancy between the ... Here is a list of the presidents and vice presidents of the United States along with their parties and dates in office. ... Chester A Arthur: Twenty-First President of the United States. 10 Interesting Facts About James Buchanan. Martin Van Buren - Eighth President of the United States. Quotes From Harry S. Truman. Malia Obama uses the stage name Malia Ann. Dia Dipasupil / Getty Images Obama, 63, noted that both Malia, 26, and her sister, Sasha, 23 , "go out of their way to not try to leverage" their ...'

# %%
from langchain.agents import Tool
from langchain.tools import BaseTool

# Defining a single tool
tools = [
    Tool(
        name = "search",
        func=search.run,
        description="useful for when you need to answer questions about current events. You should ask targeted questions"
    )
]

# %%
from langgraph.prebuilt import create_react_agent

agent_executor = create_react_agent(model, tools)

# %%
response = agent_executor.invoke({"messages": [HumanMessage(content="What time is it in London?")]})

response["messages"][2].content
# Out:
# 'The current local time in London is 16 minutes behind apparent solar time. London on the map. London is the capital of United Kingdom. Latitude: 51.51. Longitude: -0.13; Population: 8,962,000; Open London in Google Maps. Best restaurants in London #1 The Waverley Arms - British and vegetarian options food Find out the current time in London and the upcoming time changes in 2024-2027. Learn about the difference between GMT and BST, and how to install analog or digital clocks on your web page. Find out the current local time, date, time zone and daylight saving time in London, United Kingdom. Compare the time difference and distance to other major airports and cities in London. Time Zone. 0:00 hours during Greenwich Mean Time, currently in use. +1:00 hour during British Summer Time. +1:00 hour - DST is NOT in use. Sunday, March 31, 2024 at 1:00 am local time. DST starts annually the on last Sunday of March. Clocks are turned forward 1 hour to Sunday, March 31, 2024, 2:00 am local daylight time instead. Find out the current time, date, time zone, and daylight saving time in London. See sunrise and sunset times, weather, and time difference with other locations.'
