# %%
# !pdm add langchain langgraph langchain-aws duckduckgo-search langchain-community
# Out:
# Adding packages to default dependencies: langchain, langgraph, langchain-aws,
# duckduckgo-search, langchain-community
# ⠏ 0:00:00 Resolve for environment (>=3.12) None
# ⠹ 0:00:01 Resolve for environment (>=3.12) 2 resolved, 6 to resolve resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠙ 0:00:03 Resolve for environment (>=3.12) 3 resolved, 15 to resolveresolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠦ 0:00:06 Resolve for environment (>=3.12) 5 resolved, 17 to resolve resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠹ 0:00:08 Resolve for environment (>=3.12) 9 resolved, 20 to resolve resolve━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ⠦ 0:00:11 Resolve for environment (>=3.12) 21 resolved, 28 to resolve resolve91m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   0:00:25 🔒 Lock successful.  ronment (>=3.12) Fetching hashes for resolved packagesesolvee resolve0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Changes are written to pyproject.toml.
# ⠋ Resolving packages from lockfile...
# ...

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# False

# %%
from langchain_aws import ChatBedrock

model = ChatBedrock(model_id="anthropic.claude-3-5-sonnet-20240620-v1:0")

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search = DuckDuckGoSearchRun()

search.invoke("Obama's first name?")
# Out:
# 'Instead of her last name, she used just her first and middle names, Malia Ann, in the credits. And if you ask Barack Obama, his 23-year-old daughter, Sasha Obama, would do the same thing. The former first daughter and budding filmmaker now goes by Malia Ann in her professional life, aiming to separate her work from her family\'s legacy Barack Obama is opening up about his daughter ... 2 of 2. Barack Obama: timeline Key events in the life of Barack Obama. Barack Obama (born August 4, 1961, Honolulu, Hawaii, U.S.) is the 44th president of the United States (2009-17) and the first African American to hold the office. Before winning the presidency, Obama represented Illinois in the U.S. Senate (2005-08). It was reported earlier this year that Malia Obama, 26, dropped her famous last name in the credits for "The Heart," a short film that marks her directorial debut. "The Heart" was screened at the 2024 Sundance Film Festival, where the director was credited as "Malia Ann" ― a moniker tak
# ...

# %%
from langchain.agents import Tool
from langchain.tools import BaseTool

# Defining a single tool
tools = [
    Tool(
        name = "search",
        func=search.run,
        description="useful for when you need to answer questions about current events. You should ask targeted questions"
    )
]

# %%
from langgraph.prebuilt import create_react_agent

agent_executor = create_react_agent(model, tools)

# %%
from langchain_core.messages import HumanMessage

response = agent_executor.invoke({"messages": [HumanMessage(content="What time is it in London?")]})

response["messages"][2].content
# Out:
# 'The current local time in London is 16 minutes behind apparent solar time. London on the map. London is the capital of United Kingdom. Latitude: 51.51. Longitude: -0.13; Population: 8,962,000; Open London in Google Maps. Best restaurants in London #1 The Waverley Arms - British and vegetarian options food Find out the current time in London and the upcoming time changes in 2024-2027. Learn about the difference between GMT and BST, and how to install analog or digital clocks on your web page. Find out the current local time, date, time zone and daylight saving time in London, United Kingdom. Compare the time difference and distance to other major airports and cities in London. Time Zone. 0:00 hours during Greenwich Mean Time, currently in use. +1:00 hour during British Summer Time. +1:00 hour - DST is NOT in use. Sunday, March 31, 2024 at 1:00 am local time. DST starts annually the on last Sunday of March. Clocks are turned forward 1 hour to Sunday, March 31, 2024, 2:00 am local dayl
# ...
